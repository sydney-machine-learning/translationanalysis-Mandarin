# %%
# %pip install requests beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "http://www.coldbacon.com/writing/luxun-calltoarms.html#AhQ"

# %%
#translator -- Yang Hsien-yi and Gladys Yang
response = requests.get(url)

# Parse the webpage content
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Find all text elements in the page
text_elements = soup.find_all(text=True)

# chapter four
start_marker = "THE TRAGEDY OF LOVE"
end_marker = "____"
# Extract all paragraph tags
page_text = soup.get_text(separator='\n')  # Use double newlines to separate paragraphs
# Search for the start and end positions of the markers
start_pos = page_text.lower().find(start_marker.lower())
end_pos = page_text.lower().find(end_marker.lower(), start_pos)

if start_pos != -1 and end_pos != -1:
    start_pos += len(start_marker)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content = page_text[start_pos:end_pos].strip()

    # Split the extracted content into paragraphs
    paragraphs = [p.strip() for p in extracted_content.split('\n\n') if p.strip()]

    # Create a DataFrame
    df_chapt4_hsien = pd.DataFrame(paragraphs, columns=['Paragraph'])
else:
    print("Chapter markers not found.")


df_chapt4_hsien.rename(columns={'Paragraph': 'English_Verse_chap4_hsien'}, inplace=True)

# %%
#data merge


merged_rows_hsien_chapt4 = df_chapt4_hsien.iloc[31:33]
# Define a custom aggregation function
def agg(x):
    if x.dtype == 'object':
        return ' '.join(x)
    else:
        return x.sum()


merged_row_hsien_chapt4 = merged_rows_hsien_chapt4.agg(agg)

original_indices_hsien_chapt4 = merged_rows_hsien_chapt4.index

insert_index_hsien_chapt4 = original_indices_hsien_chapt4[0]

df_dropped = df_chapt4_hsien.drop(original_indices_hsien_chapt4)

merged_row_df_hsien_chapt4 = pd.DataFrame([merged_row_hsien_chapt4], index=[insert_index_hsien_chapt4])

df_with_merged_hsien_chapt4 = pd.concat([df_dropped.iloc[:insert_index_hsien_chapt4], merged_row_df_hsien_chapt4, df_dropped.iloc[insert_index_hsien_chapt4:]]).sort_index().reset_index(drop=True)

# %%
#second time merge
merged_rows_hsien_chapt4_2 = df_with_merged_hsien_chapt4.iloc[35:37]

merged_row_hsien_chapt4_2 = merged_rows_hsien_chapt4_2.agg(agg)

original_indices_hsien_chapt4_2 = merged_rows_hsien_chapt4_2.index

insert_index_hsien_chapt4_2 = original_indices_hsien_chapt4_2[0]

df_dropped_hsien_chapt4_2 = df_with_merged_hsien_chapt4.drop(original_indices_hsien_chapt4_2)

merged_row_df_hsien_chapt4_2 = pd.DataFrame([merged_row_hsien_chapt4_2], index=[insert_index_hsien_chapt4_2])

df_with_merged_hsien_chapt4_2 = pd.concat([df_dropped_hsien_chapt4_2.iloc[:insert_index_hsien_chapt4_2], merged_row_df_hsien_chapt4_2, df_dropped_hsien_chapt4_2.iloc[insert_index_hsien_chapt4_2:]]).sort_index().reset_index(drop=True)

# %%
#third time merge
merged_rows_hsien_chapt4_3 = df_with_merged_hsien_chapt4_2.iloc[39:41]

merged_row_hsien_chapt4_3 = merged_rows_hsien_chapt4_3.agg(agg)

original_indices_hsien_chapt4_3 = merged_rows_hsien_chapt4_3.index

insert_index_hsien_chapt4_3 = original_indices_hsien_chapt4_3[0]

df_dropped_hsien_chapt4_3 = df_with_merged_hsien_chapt4_2.drop(original_indices_hsien_chapt4_3)

merged_row_df_hsien_chapt4_3 = pd.DataFrame([merged_row_hsien_chapt4_3], index=[insert_index_hsien_chapt4_3])

df_with_merged_hsien_chapt4_3 = pd.concat([df_dropped_hsien_chapt4_3.iloc[:insert_index_hsien_chapt4_3], merged_row_df_hsien_chapt4_3, df_dropped_hsien_chapt4_3.iloc[insert_index_hsien_chapt4_3:]]).sort_index().reset_index(drop=True)

# %%
file_path = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_4_eng_version_hsien.csv'
df_with_merged_hsien_chapt4_3.to_csv(file_path, index=False)

# %%
#Hsien chapter five
start_marker_chapt5 = "THE PROBLEM OF LIVELIHOOD"
end_marker_chapt5 = "____"

# Search for the start and end positions of the markers
start_pos_chapt5 = page_text.lower().find(start_marker_chapt5.lower())
end_pos_chapt5 = page_text.lower().find(end_marker_chapt5.lower(), start_pos_chapt5)

if start_pos_chapt5 != -1 and end_pos_chapt5 != -1:
    start_pos_chapt5 += len(start_marker_chapt5)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content_chapt5 = page_text[start_pos_chapt5:end_pos_chapt5].strip()

    # Split the extracted content into paragraphs
    paragraphs_chapt5 = [p.strip() for p in extracted_content_chapt5.split('\n\n') if p.strip()]

    # Create a DataFrame
    df_chapt5_hsien = pd.DataFrame(paragraphs_chapt5, columns=['Paragraph'])
    print(df_chapt5_hsien)
else:
    print("Chapter markers not found.")

df_chapt5_hsien.rename(columns={'Paragraph': 'English_Verse_chap5_hsien'}, inplace=True)
df_chapt5_hsien
# Out:
#                                             Paragraph
# 0   After Ah Q had kowtowed and complied with the ...
# 1   After getting up he loafed about the streets a...
# 2   A good many days later, however, he felt even ...
# 3   When Ah Q could stand it no longer he went to ...
# 4        "There is nothing, nothing at all! Go away!"
# 5   Ah Q found it more and more extraordinary. "Th...
# 6   A few days later he did indeed meet Young D in...
# 7   "Stupid ass!" hissed Ah Q, glaring furiously a...
# 8       "I'm an insect—will that do? " asked Young D.
# 9   Such modesty only made Ah Q angrier than ever,...
# 10  "All right! All right!" exclaimed some of the ...
# 11  "Good, good!" exclaimed others, but whether to...
# 12  The two combatants turned deaf ears to them al...
# 13  "You'll be hearing from me again, curse you! ....
# 14  "Curse you! You'll be hearing from me again . ...
# 15  This epic struggle had apparently ended neithe...
# ...

# %%
file_path_hsien_chapt5 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_5_eng_version_hsien.csv'
df_chapt5_hsien.to_csv(file_path_hsien_chapt5, index=False)

# %%
#Hsien chapter 6 
start_marker_chapt6 = "FROM RESTORATION TO DECLINE"
end_marker_chapt6 = "CHAPTER 7"

# Search for the start and end positions of the markers
start_pos_chapt6 = page_text.lower().find(start_marker_chapt6.lower())
end_pos_chapt6 = page_text.lower().find(end_marker_chapt6.lower(), start_pos_chapt6)

if start_pos_chapt6 != -1 and end_pos_chapt6 != -1:
    start_pos_chapt6 += len(start_marker_chapt6)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content_chapt6 = page_text[start_pos_chapt6:end_pos_chapt6].strip()

    # Split the extracted content into paragraphs
    paragraphs_chapt6 = [p.strip() for p in extracted_content_chapt6.split('\n\n') if p.strip()]

    # Create a DataFrame
    df_chapt6_hsien = pd.DataFrame(paragraphs_chapt6, columns=['Paragraph'])
else:
    print("Chapter markers not found.")

df_chapt6_hsien.rename(columns={'Paragraph': 'English_Verse_chap6_hsien'}, inplace=True)
df_chapt6_hsien
# Out:
#                             English_Verse_chap6_hsien
# 0   Weichuang did not see Ah Q again till just aft...
# 1   Ah Q's return this time was very different fro...
# 2                      "Hullo, Ah Q, so you're back!"
# 3                                    "Yes, I'm back."
# 4      "You've made money . . . er . . . where. . .?"
# 5                                   "I went to town."
# 6   By the next day this piece of news had spread ...
# 7   According to Ah Q, he had been a servant in th...
# 8   According to Ah Q, his return was also due to ...
# 9   "Have you seen an execution?" asked Ah Q. "Ah,...
# 10                              "Kill!" shouted Ah Q.
# 11  Whiskers Wang gave a start, and drew in his he...
# 12  Although we cannot say that in the eyes of the...
# 13  Not long after, Ah Q's fame suddenly spread in...
# 14  Then those who had no silk skirt or needed for...
# 15  "Ah Q, have you any more silk skirts?" they wo...
# ...

# %%
df_chapt6_hsien.iloc[13]
# Out:
# English_Verse_chap6_hsien    Not long after, Ah Q's fame suddenly spread in...
# Name: 13, dtype: object

# %%
#merge rows
merged_rows_hsien_chapt6_1 = df_chapt6_hsien.iloc[13:15]
# Define a custom aggregation function
def agg(x):
    if x.dtype == 'object':
        return ' '.join(x)
    else:
        return x.sum()


merged_row_hsien_chapt6_1 = merged_rows_hsien_chapt6_1.agg(agg)

original_indices_hsien_chapt6_1 = merged_rows_hsien_chapt6_1.index

insert_index_hsien_chapt6_1 = original_indices_hsien_chapt6_1[0]

df_dropped_chapt6_1 = df_chapt6_hsien.drop(original_indices_hsien_chapt6_1)

merged_row_df_hsien_chapt6_1 = pd.DataFrame([merged_row_hsien_chapt6_1], index=[insert_index_hsien_chapt6_1])

df_with_merged_hsien_chapt6_1 = pd.concat([df_dropped_chapt6_1.iloc[:insert_index_hsien_chapt6_1], merged_row_df_hsien_chapt6_1, df_dropped_chapt6_1.iloc[insert_index_hsien_chapt6_1:]]).sort_index().reset_index(drop=True)

# %%
merged_rows_hsien_chapt6_2 = df_with_merged_hsien_chapt6_1.iloc[15:17]

merged_row_hsien_chapt6_2 = merged_rows_hsien_chapt6_2.agg(agg)

original_indices_hsien_chapt6_2 = merged_rows_hsien_chapt6_2.index

insert_index_hsien_chapt6_2 = original_indices_hsien_chapt6_2[0]

df_dropped_chapt6_2 = df_with_merged_hsien_chapt6_1.drop(original_indices_hsien_chapt6_2)

merged_row_df_hsien_chapt6_2 = pd.DataFrame([merged_row_hsien_chapt6_2], index=[insert_index_hsien_chapt6_2])

df_with_merged_hsien_chapt6_2 = pd.concat([df_dropped_chapt6_2.iloc[:insert_index_hsien_chapt6_2], merged_row_df_hsien_chapt6_2, df_dropped_chapt6_2.iloc[insert_index_hsien_chapt6_2:]]).sort_index().reset_index(drop=True)

# %%
merged_rows_hsien_chapt6_3 = df_with_merged_hsien_chapt6_2.iloc[29:31]

merged_row_hsien_chapt6_3 = merged_rows_hsien_chapt6_3.agg(agg)

original_indices_hsien_chapt6_3 = merged_rows_hsien_chapt6_3.index

insert_index_hsien_chapt6_3 = original_indices_hsien_chapt6_3[0]

df_dropped_chapt6_3 = df_with_merged_hsien_chapt6_2.drop(original_indices_hsien_chapt6_3)

merged_row_df_hsien_chapt6_3 = pd.DataFrame([merged_row_hsien_chapt6_3], index=[insert_index_hsien_chapt6_3])

df_with_merged_hsien_chapt6_3 = pd.concat([df_dropped_chapt6_3.iloc[:insert_index_hsien_chapt6_3], merged_row_df_hsien_chapt6_3, df_dropped_chapt6_3.iloc[insert_index_hsien_chapt6_3:]]).sort_index().reset_index(drop=True)

# %%
merged_rows_hsien_chapt6_4 = df_with_merged_hsien_chapt6_3.iloc[31:33]

merged_row_hsien_chapt6_4 = merged_rows_hsien_chapt6_4.agg(agg)

original_indices_hsien_chapt6_4 = merged_rows_hsien_chapt6_4.index

insert_index_hsien_chapt6_4 = original_indices_hsien_chapt6_4[0]

df_dropped_chapt6_4 = df_with_merged_hsien_chapt6_3.drop(original_indices_hsien_chapt6_4)

merged_row_df_hsien_chapt6_4 = pd.DataFrame([merged_row_hsien_chapt6_4], index=[insert_index_hsien_chapt6_4])

df_with_merged_hsien_chapt6_4 = pd.concat([df_dropped_chapt6_4.iloc[:insert_index_hsien_chapt6_4], merged_row_df_hsien_chapt6_4, df_dropped_chapt6_4.iloc[insert_index_hsien_chapt6_4:]]).sort_index().reset_index(drop=True)

# %%
file_path_hsien_chapt6 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_6_eng_version_hsien.csv'
df_with_merged_hsien_chapt6_4.to_csv(file_path_hsien_chapt6, index=False)

# %%
#google translation
import requests
import pandas as pd
import re

# URL of the text file
url = "http://www.xys.org/xys/classics/Lu-Xun/Nahan/aq.txt"

# Send a request to the text file
response = requests.get(url)
page_text = response.text

# Define the start and end markers in Chinese
start_marker_ch = "恋爱的悲剧"  # Example start marker in Chinese (Tragedy of Love)
end_marker_ch = "第五章"  # Example end marker in Chinese (Chapter 5)

# Search for the start and end positions of the markers
start_pos_ch = page_text.find(start_marker_ch)
end_pos_ch = page_text.find(end_marker_ch, start_pos_ch)

if start_pos_ch != -1 and end_pos_ch != -1:
    start_pos_ch += len(start_marker_ch)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content_ch = page_text[start_pos_ch:end_pos_ch].strip()

    # Split the extracted content into paragraphs based on double newlines
    paragraphs_ch = re.split(r'\n\s*\n', extracted_content_ch)
    # Replace single newlines within paragraphs with spaces
    paragraphs_ch = [re.sub(r'\s*\n\s*', ' ', p).strip() for p in paragraphs_ch if p.strip()]

    # Create a DataFrame
    df_ch = pd.DataFrame(paragraphs_ch, columns=['Paragraph'])
    print(df_ch)
else:
    print("Chapter markers not found.")
# Out:
#                                             Paragraph
# 0   有人说：有些胜利者，愿意敌手如虎，如鹰，他才感得胜利的欢喜；假使如羊 ，如小鸡，他便反觉得胜...
# 1                                     看哪，他飘飘然的似乎要飞去了！
# 2   然而这一次的胜利，却又使他有些异样。他飘飘然的飞了大半天，飘进土谷祠 ，照例应该躺下便打鼾。...
# 3                                          “断子绝孙的阿Ｑ！”
# 4   阿Ｑ的耳朵里又听到这句话。他想：不错，应该有一个女人，断子绝孙便没有 人供一碗饭，……应该有...
# 5                                       “女人，女人！……”他想。
# 6                           “……和尚动得……女人，女人！……女人！”他又想。
# 7   我们不能知道这晚上阿Ｑ在什么时候才打鼾。但大约他从此总觉得指头有些滑 腻，所以他从此总有些飘...
# 8                               即此一端，我们便可以知道女人是害人的东西。
# 9   中国的男人，本来大半都可以做圣贤，可惜全被女人毁掉了。商是妲己⑩闹亡 的；周是褒姒弄坏的；秦...
# 10  阿Ｑ本来也是正人，我们虽然不知道他曾蒙什么明师指授过，但他对于“男女 之大防”㈠却历来非常严...
# 11  谁知道他将到“而立”㈢之年，竟被小尼姑害得飘飘然了。这飘飘然的精神， 在礼教上是不应该有的，...
# 12                                          “女……”阿Ｑ想。
# 13  他对于以为“一定想引诱野男人”的女人，时常留心看，然而伊并不对他笑。 他对于和他讲话的女人，...
# 14  这一天，阿Ｑ在赵太爷家里舂了一天米，吃过晚饭，便坐在厨房里吸旱烟。倘 在别家，吃过晚饭本可以...
# 15          吴妈，是赵太爷家里唯一的女仆，洗完了碗碟，也就在长凳上坐下了，而且和 阿Ｑ谈闲天：
# ...

# %%
merged_rows = df_ch.iloc[39:44]

# Define a custom aggregation function
def agg(x):
    if x.dtype == 'object':
        return ' '.join(x)
    else:
        return x.sum()


merged_row = merged_rows.agg(agg)

original_indices = merged_rows.index

insert_index = original_indices[0]

df_dropped = df_ch.drop(original_indices)

merged_row_df = pd.DataFrame([merged_row], index=[insert_index])

df_with_merged = pd.concat([df_dropped.iloc[:insert_index], merged_row_df, df_dropped.iloc[insert_index:]]).sort_index().reset_index(drop=True)

print(df_with_merged)
# Out:
#                                             Paragraph
# 0   有人说：有些胜利者，愿意敌手如虎，如鹰，他才感得胜利的欢喜；假使如羊 ，如小鸡，他便反觉得胜...
# 1                                     看哪，他飘飘然的似乎要飞去了！
# 2   然而这一次的胜利，却又使他有些异样。他飘飘然的飞了大半天，飘进土谷祠 ，照例应该躺下便打鼾。...
# 3                                          “断子绝孙的阿Ｑ！”
# 4   阿Ｑ的耳朵里又听到这句话。他想：不错，应该有一个女人，断子绝孙便没有 人供一碗饭，……应该有...
# 5                                       “女人，女人！……”他想。
# 6                           “……和尚动得……女人，女人！……女人！”他又想。
# 7   我们不能知道这晚上阿Ｑ在什么时候才打鼾。但大约他从此总觉得指头有些滑 腻，所以他从此总有些飘...
# 8                               即此一端，我们便可以知道女人是害人的东西。
# 9   中国的男人，本来大半都可以做圣贤，可惜全被女人毁掉了。商是妲己⑩闹亡 的；周是褒姒弄坏的；秦...
# 10  阿Ｑ本来也是正人，我们虽然不知道他曾蒙什么明师指授过，但他对于“男女 之大防”㈠却历来非常严...
# 11  谁知道他将到“而立”㈢之年，竟被小尼姑害得飘飘然了。这飘飘然的精神， 在礼教上是不应该有的，...
# 12                                          “女……”阿Ｑ想。
# 13  他对于以为“一定想引诱野男人”的女人，时常留心看，然而伊并不对他笑。 他对于和他讲话的女人，...
# 14  这一天，阿Ｑ在赵太爷家里舂了一天米，吃过晚饭，便坐在厨房里吸旱烟。倘 在别家，吃过晚饭本可以...
# 15          吴妈，是赵太爷家里唯一的女仆，洗完了碗碟，也就在长凳上坐下了，而且和 阿Ｑ谈闲天：
# ...

# %%
from googletrans import Translator, LANGUAGES

translator = Translator()

for col in df_with_merged.columns:
    for i in range(len(df_with_merged)):
        text = df_with_merged.at[i, col]
        translated = translator.translate(text, src='zh-cn', dest='en')
        df_with_merged.at[i, col] = translated.text

df_with_merged.iloc[30]
# Out:
# Paragraph    When he too off his clothes, heard that he was...
# Name: 30, dtype: object

# %%
df_with_merged.iloc[31]
# Out:
# Paragraph    The Young Grandmother was drawging wz's mother...
# Name: 31, dtype: object

# %%
#merge
merged_rows_google_chapt4 = df_with_merged.iloc[31:33]

# Define a custom aggregation function
def agg(x):
    if x.dtype == 'object':
        return ' '.join(x)
    else:
        return x.sum()


merged_row_google_chapt4 = merged_rows_google_chapt4.agg(agg)

original_indices_google_chapt4 = merged_rows_google_chapt4.index

insert_index_google_chapt4 = original_indices_google_chapt4[0]

df_dropped = df_with_merged.drop(original_indices_google_chapt4)

merged_row_df_google_chapt4 = pd.DataFrame([merged_row_google_chapt4], index=[insert_index_google_chapt4])

df_with_merged_google_chapt4 = pd.concat([df_dropped.iloc[:insert_index_google_chapt4], merged_row_df_google_chapt4, df_dropped.iloc[insert_index_google_chapt4:]]).sort_index().reset_index(drop=True)

print(df_with_merged_google_chapt4)
# Out:
#                                             Paragraph
# 0   SOME people say: some winners are Willing to b...
# 1                     Seeing, he seemed to be flying!
# 2   However, This Victory Made Him a Little Strang...
# 3                            "Broken Son's Grandson!"
# 4   This sense was heard agin in aqi's elegt: yes,...
# 5                       "WOMAN, WOMAN! ..." he think.
# 6   "... The Monk Moved ... Woman, WOMAN! ... Woma...
# 7   We cannot know when aq is snoring this night.b...
# 8   That is, we can knowing that situation are har...
# 9   MOST CHINESE MEN COLD HAVE Been Sages, But Uni...
# 10  Aya was originally a positive person. Although...
# 11  Who Knew that he friend be in the "embarra" ye...
# 12                           "Female ..." ah Thought.
# 13  He often attention to the water who thinks "wh...
# 14  On this day, aqi too, a day in the house of Ta...
# 15  Wu ma is the only maid in the house of Taiye z...
# ...

# %%
df_with_merged_google_chapt4.rename(columns={'Paragraph': 'English_Verse_chap4_google'}, inplace=True)
#store to csv
file_path_google_chapt4 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_4_eng_version_google.csv'
df_with_merged_google_chapt4.to_csv(file_path_google_chapt4, index=False)

# %%
# Define the start and end markers in Chinese
start_marker_ch_chapt5 = "生计问题"  # Example start marker in Chinese (Tragedy of Love)
end_marker_ch_chapt5 = "第六章"  # Example end marker in Chinese (Chapter 5)

# Search for the start and end positions of the markers
start_pos_ch_chapt5 = page_text.find(start_marker_ch_chapt5)
end_pos_ch_chapt5 = page_text.find(end_marker_ch_chapt5, start_pos_ch_chapt5)

if start_pos_ch_chapt5 != -1 and end_pos_ch_chapt5 != -1:
    start_pos_ch_chapt5 += len(start_marker_ch_chapt5)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content_ch_chapt5 = page_text[start_pos_ch_chapt5:end_pos_ch_chapt5].strip()

    # Split the extracted content into paragraphs based on double newlines
    paragraphs_ch_chapt5 = re.split(r'\n\s*\n', extracted_content_ch_chapt5)
    paragraphs_ch_chapt5 = [re.sub(r'\s*\n\s*', ' ', p).strip() for p in paragraphs_ch_chapt5 if p.strip()]

    # Create a DataFrame
    df_ch_chapt5 = pd.DataFrame(paragraphs_ch_chapt5, columns=['Paragraph'])
    print(df_ch_chapt5)
else:
    print("Chapter markers not found.")
# Out:
#                                             Paragraph
# 0   阿Ｑ礼毕之后，仍旧回到土谷祠，太阳下去了，渐渐觉得世上有些古怪。他仔 细一想，终于省悟过来：...
# 1   他起来之后，也仍旧在街上逛，虽然不比赤膊之有切肤之痛，却又渐渐的觉得 世上有些古怪了。仿佛从...
# 2   但他更觉得世上有些古怪，却是许多日以后的事。其一，酒店不肯赊欠了；其 二，管土谷祠的老头子说...
# 3   阿Ｑ忍不下去了，他只好到老主顾的家里去探问，——但独不许踏进赵府的门 槛，——然而情形也异样...
# 4                                         “没有没有！你出去！”
# 5   阿Ｑ愈觉得稀奇了。他想，这些人家向来少不了要帮忙，不至于现在忽然都无 事，这总该有些蹊跷在里...
# 6                                      “我手执钢鞭将你打！㈤……”
# 7      几天之后，他竟在钱府的照壁前遇见了小Ｄ。“仇人相见分外眼明”，阿Ｑ便 迎上去，小Ｄ也站住了。
# 8                             “畜生！”阿Ｑ怒目而视的说，嘴角上飞出唾沫来。
# 9                                    “我是虫豸，好么？……”小Ｄ说。
# 10  这谦逊反使阿Ｑ更加愤怒起来，但他手里没有钢鞭，于是只得扑上去，伸手去 拔小Ｄ的辫子。小Ｄ一手...
# 11                              “好了，好了！”看的人们说，大约是解劝的。
# 12                       “好，好！”看的人们说，不知道是解劝，是颂扬，还是煽动。
# 13  然而他们都不听。阿Ｑ进三步，小Ｄ便退三步，都站着；小Ｄ进三步，阿Ｑ便 退三步，又都站着。大约...
# 14                                “记着罢，妈妈的……”阿Ｑ回过头去说。
# 15                               “妈妈的，记着罢……”小Ｄ也回过头来说。
# ...

# %%
#google translator
for col in df_ch_chapt5.columns:
    for i in range(len(df_ch_chapt5)):
        text = df_ch_chapt5.at[i, col]
        translated = translator.translate(text, src='zh-cn', dest='en')
        df_ch_chapt5.at[i, col] = translated.text

df_ch_chapt5
# Out:
#                                             Paragraph
# 0   After Ayei, he still returned to Tugu Temple. ...
# 1   After he got up, he still strolled on the stre...
# 2   But he felt a little weird in the world, but i...
# 3   Aq couldn't bear it anymore, he had to go to t...
# 4                                   "No! You go out!"
# 5   The more Aq feels strange.He thought that thes...
# 6                      "I hold you with a steel whip!
# 7   A few days later, he met Xiao D in front of Qi...
# 8   "Beast!" Ah said angrily, spitting from the co...
# 9                "I'm a worm, okay? ..." Xiao D said.
# 10  This humility made Ah even more angry, but he ...
# 11  "Okay, okay!" The people who watched said, it ...
# 12  "Okay, okay!" The people said, I don't know if...
# 13  But they don't listen.Aqi entered three steps,...
# 14            "Remember, my mother ..." Ai said back.
# 15       "Mom, remember ..." Xiao D also turned back.
# ...

# %%
df_ch_chapt5.rename(columns={'Paragraph': 'English_Verse_chap5_google'}, inplace=True)
#store to csv
file_path_google_chapt5 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_5_eng_version_google.csv'
df_ch_chapt5.to_csv(file_path_google_chapt5, index=False)

# %%
start_marker_ch_chapt6 = "从中兴到末路"  
end_marker_ch_chapt6 = "第七章"  

# Search for the start and end positions of the markers
start_pos_ch_chapt6 = page_text.find(start_marker_ch_chapt6)
end_pos_ch_chapt6 = page_text.find(end_marker_ch_chapt6, start_pos_ch_chapt6)

if start_pos_ch_chapt6 != -1 and end_pos_ch_chapt6 != -1:
    start_pos_ch_chapt6 += len(start_marker_ch_chapt6)  # Adjust to start after the marker
    # Extract the text between the markers
    extracted_content_ch_chapt6 = page_text[start_pos_ch_chapt6:end_pos_ch_chapt6].strip()

    # Split the extracted content into paragraphs based on double newlines
    paragraphs_ch_chapt6 = re.split(r'\n\s*\n', extracted_content_ch_chapt6)
    paragraphs_ch_chapt6 = [re.sub(r'\s*\n\s*', ' ', p).strip() for p in paragraphs_ch_chapt6 if p.strip()]

    # Create a DataFrame
    df_ch_chapt6 = pd.DataFrame(paragraphs_ch_chapt6, columns=['Paragraph'])
    print(df_ch_chapt6)
else:
    print("Chapter markers not found.")
# Out:
#                                             Paragraph
# 0   在未庄再看见阿Ｑ出现的时候，是刚过了这年的中秋。人们都惊异，说是阿Ｑ 回来了，于是又回上去想...
# 1   但阿Ｑ这回的回来，却与先前大不同，确乎很值得惊异。天色将黑，他睡眼蒙 胧的在酒店门前出现了，...
# 2                                        “豁，阿Ｑ，你回来了！”
# 3                                              “回来了。”
# 4                                      “发财发财，你是——在……”
# 5                                             “上城去了！”
# 6   这一件新闻，第二天便传遍了全未庄。人人都愿意知道现钱和新夹袄的阿Ｑ的 中兴史，所以在酒店里，...
# 7   据阿Ｑ说，他是在举人老爷家里帮忙。这一节，听的人都肃然了。这老爷本姓 白，但因为合城里只有他...
# 8   据阿Ｑ说，他的回来，似乎也由于不满意城里人，这就在他们将长凳称为条凳 ，而且煎鱼用葱丝，加以...
# 9   “你们可看见过杀头么？”阿Ｑ说，“咳，好看。杀革命党。唉，好看好看， ……”他摇摇头，将唾沫...
# 10                                               “嚓！”
# 11  王胡惊得一跳，同时电光石火似的赶快缩了头，而听的人又都悚然而且欣然了 。从此王胡瘟头瘟脑的许...
# 12     阿Ｑ这时在未庄人眼睛里的地位，虽不敢说超过赵太爷，但谓之差不多，大约 也就没有什么语病的了。
# 13  然而不多久，这阿Ｑ的大名忽又传遍了未庄的闺中。虽然未庄只有钱赵两姓是 大屋，此外十之九都是浅...
# 14                           “阿Ｑ，你还有绸裙么？没有？纱衫也要的，有罢？”
# 15  后来这终于从浅闺传进深闺里去了。因为邹七嫂得意之余，将伊的绸裙请赵太 太去鉴赏，赵太太又告诉...
# ...

# %%
#google translator
for col in df_ch_chapt6.columns:
    for i in range(len(df_ch_chapt6)):
        text = df_ch_chapt6.at[i, col]
        translated = translator.translate(text, src='zh-cn', dest='en')
        df_ch_chapt6.at[i, col] = translated.text

df_ch_chapt6
# Out:
#                                             Paragraph
# 0   When I saw Aqi's appearance again, it was just...
# 1   But Aq's return this time is very different fr...
# 2                           "Open, Ah, you are back!"
# 3                                        "came back."
# 4              "Fortune to get rich, you are -in ..."
# 5                                   "Go to the city!"
# 6   This news spread all over the next day.Everyon...
# 7   According to Aqi, he was helping the master's ...
# 8   According to Aqi, his return seems to be dissa...
# 9   "Have you ever seen the killing head?" Ai said...
# 10                                             "Hey!"
# 11  Wang Hu was shocked, and at the same time, he ...
# 12  At this time, Aqi's status in the eyes of Weiz...
# 13  However, not long after, the name of this Aya ...
# 14  "Ah, do you have a silk skirt? No? Do you want...
# 15  Later, this finally passed from the shallow gi...
# ...

# %%
df_ch_chapt6.rename(columns={'Paragraph': 'English_Verse_chap6_google'}, inplace=True)
#store to csv
file_path_google_chapt6 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_6_eng_version_google.csv'
df_ch_chapt6.to_csv(file_path_google_chapt6, index=False)

# %%
# %pip install PyPDF2
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Julia Lovell
import PyPDF2

# Open the PDF file in read-binary mode
with open('/Users/wangxuechun/Desktop/data_preparation/Version_by_YiyunLi_chapt6.pdf', 'rb') as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)

    # Initialize an empty string to store the text
    pdf_text = ''

    # Iterate through the pages and extract text
    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        pdf_text += page.extract_text()
    # test

print(pdf_text)
# Out:
# Weizhuang did not catch another glimpse of Ah-Q until just past the Mid-Autumn Festival. Remarking in surprise upon his sudden return, the villagers suddenly wondered where he had been all this time. Whenever he had taken himself off to town before, Ah-Q had been quick to mouth off about it. This time, however, he had kept curiously quiet, so no one had paid any attention. Maybe he had told the old caretaker in the temple. In any case, only trips to town undertaken by people of consequence - by Messrs Zhao or Qian, or the local genius - were public events in Weizhuang. If even the exploits of the Fake Foreign Devil failed to count as newsworthy, then what claim did Ah-Q have on the village's notice? Maybe that was why the old man had not broadcast the news, leaving the rest of Weizhuang society in the dark. @  Yet Ah-Q seemed changed - even remarkably so - on his return from this particular trip. One evening, near nightfall, he suddenly appeared, sleepy-eyed, in the doorway to the ta
# ...

# %%
verses = [verse.strip() for verse in pdf_text.strip().split('@') if verse]
print(len(verses))
# Out:
# 32

# %%
import os
import pandas as pd

#create a dataframe to store the chinese paragraph and english paragraph
df_yiyun_chapt6 = pd.DataFrame({
    'English_Verse_chap6_julia': verses,
})

#store the csv format in the desktop 
desktop = os.path.join(os.path.join(os.path.expanduser('~')), 'Desktop')
filepath = os.path.join(desktop, 'chapter_6_eng_version_julia.csv')
df_yiyun_chapt6.to_csv(filepath, index=False)

# %%
#preprocesss data
df_julia_chapt4 = pd.read_csv('/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_4_eng_version_julia.csv')
print(df_julia_chapt4)
merged_rows_julia = df_julia_chapt4.iloc[38:43]

# Define a custom aggregation function
def agg(x):
    if x.dtype == 'object':
        return ' '.join(x)
    else:
        return x.sum()


merged_row_julia = merged_rows_julia.agg(agg)

original_indices_julia = merged_rows_julia.index

insert_index_julia = original_indices_julia[0]

df_dropped = df_julia_chapt4.drop(original_indices_julia)

merged_row_df_julia = pd.DataFrame([merged_row_julia], index=[insert_index_julia])

df_with_merged_julia = pd.concat([df_dropped.iloc[:insert_index_julia], merged_row_df_julia, df_dropped.iloc[insert_index_julia:]]).sort_index().reset_index(drop=True)

print(df_with_merged_julia)

file_path_julia_chapt4 = '/Users/wangxuechun/unsw/thesis-repo/data_processing/chapter_4_eng_version_julia.csv'
df_with_merged_julia.to_csv(file_path_julia_chapt4, index=False)
# Out:
#                             English_Verse_chap4_julia
# 0   There are, it is said, some victors who deligh...
# 1   See him now: walking on air after a busy day o...
# 2   This latest victory, however, did bring an unu...
# 3                  'May you die without descendants!'
# 4   Echoed in the cathedral of Ah-Q's mind. 'She's...
# 5     'Woman..."he thought. 'Must... find... woman...
# 6   'Sauce for the goose..." he thought some more,...
# 7   As to when, exactly, Ah-Q began snoring that e...
# 8   Irrefutable proof that women are at the root o...
# 9   The great majority of Chinese men in history w...
# 10  Until this point in his career, Ah-Q had been ...
# 11  Yet here he was, at the age of thirty - the ye...
# 12                   'Woman..' Ah-Q went on thinking.
# 13  Ah-Q often kept women he suspected of having d...
# 14  One evening, after a day spent husking rice at...
# 15  Once the dishes were done, Mrs Wu, the Zhaos' ...
# ...
